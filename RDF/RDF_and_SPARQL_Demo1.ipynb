# %%
# !pip install SPARQLWrapper pandas

import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
from IPython.display import display, HTML
import time

# Configure display
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
# Out:
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting rdflib>=6.1.1 (from SPARQLWrapper)
#   Downloading rdflib-7.4.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.2.5)
# Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Downloading rdflib-7.4.0-py3-none-any.whl (569 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 569.0/569.0 kB 11.4 MB/s eta 0:00:00
# Installing collected packages: rdflib, SPARQLWrapper
# Successfully installed SPARQLWrapper-2.0.0 rdflib-7.4.0

# %%
# COMMON PREFIXES FOR DBpedia FILM QUERIES
PREFIXES = """
PREFIX dbo: <http://dbpedia.org/ontology/>
PREFIX dbr: <http://dbpedia.org/resource/>
PREFIX dbp: <http://dbpedia.org/property/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
"""
print("DBpedia Film SPARQL Prefixes Defined:")
print(PREFIXES)
# Out:
# DBpedia Film SPARQL Prefixes Defined:
#
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

# %%
class DBpediaFilmExecutor:
    def __init__(self):
        self.endpoint = "https://dbpedia.org/sparql"
        self.sparql = SPARQLWrapper(self.endpoint)
        self.sparql.setTimeout(120)  # Increase timeout for complex queries

    def execute_query(self, query, description, delay=2):
        """Execute SPARQL query and display results"""

        display(HTML(f"<h3>{description}</h3>"))
        display(HTML(f"<h4> Query:</h4>"))

        # Combine prefixes with query
        full_query = PREFIXES + query
        display(HTML(f"<pre><code>{full_query}</code></pre>"))

        display(HTML(f"<h4> Results:</h4>"))

        try:
            self.sparql.setQuery(full_query)
            self.sparql.setReturnFormat(JSON)

            # Add delay to be respectful to the endpoint
            time.sleep(delay)

            results = self.sparql.query().convert()

            if 'boolean' in results:
                display(HTML(f"<p>ASK Result: <b>{results['boolean']}</b></p>"))
            elif 'results' in results and results['results']['bindings']:
                df = self._format_dataframe(results)
                display(HTML(f"<p>Found {len(df)} results</p>"))
                display(df)
            else:
                display(HTML("<p>No results found</p>"))
                display(HTML("<p><i>Try modifying the query parameters</i></p>"))

        except Exception as e:
            display(HTML(f"<p>Query execution error: {str(e)}</p>"))
            display(HTML("<p><i>This might be due to endpoint load or query complexity</i></p>"))

    def _format_dataframe(self, results):
        """Convert SPARQL results to pandas DataFrame"""
        columns = results['head']['vars']
        data = []

        for result in results['results']['bindings']:
            row = {}
            for column in columns:
                if column in result:
                    # Extract just the value for display
                    value = result[column]['value']
                    # Shorten long URIs for better display
                    if 'dbpedia.org' in value and '/' in value:
                        value = value.split('/')[-1]
                    row[column] = value
                else:
                    row[column] = None
            data.append(row)

        return pd.DataFrame(data)

# Initialize executor
executor = DBpediaFilmExecutor()

print("DBpedia Film SPARQL Executor Ready!")
# Out:
# DBpedia Film SPARQL Executor Ready!

# %%
query_1 = """
SELECT ?film ?title ?releaseDate ?director ?runtime
WHERE {
    # ?film rdf:type dbo:Film ;
          rdfs:label ?title ;
          dbo:releaseDate ?releaseDate .

    # Optional director information
    OPTIONAL {
        # ?film dbo:director ?director .
        # ?director foaf:name ?directorName .
    }

    # Optional runtime information
    OPTIONAL {
        # ?film dbo:runtime ?runtime .
    }

    FILTER (YEAR(?releaseDate) >= 2010 && YEAR(?releaseDate) <= 2015)
    FILTER (LANG(?title) = 'en')
}
ORDER BY ?releaseDate
LIMIT 20
"""

executor.execute_query(query_1, "Query 1: Films from 2010-2015 with Basic Information")
# Out:
# <h3>Query 1: Films from 2010-2015 with Basic Information</h3>
# <h4> Query:</h4>
# <pre><code>
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT ?film ?title ?releaseDate ?director ?runtime
# WHERE {
#     ?film rdf:type dbo:Film ;
#           rdfs:label ?title ;
#           dbo:releaseDate ?releaseDate .
#
#     # Optional director information
#     OPTIONAL {
#         ?film dbo:director ?director .
#         ?director foaf:name ?directorName .
#     }
#
#     # Optional runtime information
#     OPTIONAL {
#         ?film dbo:runtime ?runtime .
#     }
#
#     FILTER (YEAR(?releaseDate) >= 2010 && YEAR(?releaseDate) <= 2015)
#     FILTER (LANG(?title) = 'en')
# }
# ORDER BY ?releaseDate
# LIMIT 20
# </code></pre>
# <h4> Results:</h4>
# <p>Found 20 results</p>
#                                     film  \
# 0                               Natarang
# 1                               Ryōmaden
# 2                               Ryōmaden
# 3            Tough_Nights_of_Club_Indigo
# 4            Trauma_(Canadian_TV_series)
# 5      The_Pharaoh_Who_Conquered_the_Sea
# 6                           Black_Ransom
# 7                        Shoot_the_Hero!
# 8   Ploddy_the_Police_Car_Makes_a_Splash
# 9                             Mighty_Uke
# 10               Mi_Hiyy_Keekkuraanee%3F
# 11             Material_Girl_(TV_series)
# 12                      Bellamy's_People
# 13         Chemistry:_A_Volatile_History
# 14           Pet_Pals:_Marco_Polo's_Code
# 15                    The_Pregnancy_Pact
# 16                Fear_the_Boom_and_Bust
# 17                      Uno_(video_game)
# 18                     Bad_Family_(film)
# 19                       Socks_and_Cakes
#
#                                    title releaseDate             director  \
# 0                               Natarang  2010-01-01          Ravi_Jadhav
# 1                               Ryōmaden  2010-01-03         Keishi_Ōtomo
# 2                               Ryōmaden  2010-01-03         Keishi_Ōtomo
# 3            Tough Nights of Club Indigo  2010-01-05                 None
# 4            Trauma (Canadian TV series)  2010-01-05                 None
# 5      The Pharaoh Who Conquered the Sea  2010-01-06                 None
# 6                           Black Ransom  2010-01-07            Wong_Jing
# 7                        Shoot the Hero!  2010-01-08                 None
# 8   Ploddy the Police Car Makes a Splash  2010-01-08  Rasmus_A._Sivertsen
# 9                             Mighty Uke  2010-01-11                 None
# 10                 Mi Hiyy Keekkuraanee?  2010-01-13        Amjad_Ibrahim
# 11             Material Girl (TV series)  2010-01-14                 None
# 12                      Bellamy's People  2010-01-21      Paul_Whitehouse
# 13         Chemistry: A Volatile History  2010-01-21                 None
# 14           Pet Pals: Marco Polo's Code  2010-01-22                 None
# 15                    The Pregnancy Pact  2010-01-23   Rosemary_Rodriguez
# 16                Fear the Boom and Bust  2010-01-23                 None
# 17                      Uno (video game)  2010-01-25                 None
# 18                     Bad Family (film)  2010-01-29    Aleksi_Salmenperä
# 19                       Socks and Cakes  2010-01-29      Antonio_Padovan
#
#    runtime
# 0   7200.0
# 1   4500.0
# 2   2700.0
# 3     None
# 4     None
# 5     None
# 6   5580.0
# 7   4800.0
# 8   4440.0
# 9   4560.0
# 10    None
# 11  3600.0
# 12  1800.0
# 13  3600.0
# 14  5700.0
# 15  5220.0
# 16   453.0
# 17    None
# 18  5700.0
# 19   780.0

# %%
query_2 = """
SELECT ?decade
       (COUNT(?film) AS ?filmCount)
       (AVG(?runtime) AS ?avgRuntime)
       (MIN(YEAR(?releaseDate)) AS ?firstYear)
       (MAX(YEAR(?releaseDate)) AS ?lastYear)
WHERE {
    # ?film rdf:type dbo:Film ;
          dbo:releaseDate ?releaseDate .

    # Optional runtime for average calculation
    OPTIONAL {
        # ?film dbo:runtime ?runtime .
    }

    # Group by decade
    BIND (FLOOR(YEAR(?releaseDate)/10)*10 AS ?decade)

    FILTER (YEAR(?releaseDate) >= 1980)
}
GROUP BY ?decade
HAVING (COUNT(?film) > 10)
ORDER BY ?decade
"""

executor.execute_query(query_2, "Query 2: Film Statistics by Decade (1980+)")
# Out:
# <h3>Query 2: Film Statistics by Decade (1980+)</h3>
# <h4> Query:</h4>
# <pre><code>
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT ?decade
#        (COUNT(?film) AS ?filmCount)
#        (AVG(?runtime) AS ?avgRuntime)
#        (MIN(YEAR(?releaseDate)) AS ?firstYear)
#        (MAX(YEAR(?releaseDate)) AS ?lastYear)
# WHERE {
#     ?film rdf:type dbo:Film ;
#           dbo:releaseDate ?releaseDate .
#
#     # Optional runtime for average calculation
#     OPTIONAL {
#         ?film dbo:runtime ?runtime .
#     }
#
#     # Group by decade
#     BIND (FLOOR(YEAR(?releaseDate)/10)*10 AS ?decade)
#
#     FILTER (YEAR(?releaseDate) >= 1980)
# }
# GROUP BY ?decade
# HAVING (COUNT(?film) > 10)
# ORDER BY ?decade
# </code></pre>
# <h4> Results:</h4>
# <p>Found 5 results</p>
#   decade filmCount            avgRuntime firstYear lastYear
# 0   1980      1907  6126.796742671009772      1980     1989
# 1   1990      2285  5976.766944734098019      1990     1999
# 2   2000      3513  6844.165820178448868      2000     2009
# 3   2010      2552  6358.278006012024048      2010     2019
# 4   2020       356  5768.654901960784314      2020     2024

# %%
query_3 = """
SELECT ?film ?title ?releaseDate ?genre ?country ?language ?budget
WHERE {
    # ?film rdf:type dbo:Film ;
          rdfs:label ?title ;
          dbo:releaseDate ?releaseDate .

    # Optional genre information
    OPTIONAL {
        # ?film dbo:genre ?genre .
        # ?genre rdfs:label ?genreLabel .
        FILTER (LANG(?genreLabel) = 'en')
    }

    # Optional country information
    OPTIONAL {
        # ?film dbo:country ?country .
        # ?country rdfs:label ?countryLabel .
        FILTER (LANG(?countryLabel) = 'en')
    }

    # Optional language information
    OPTIONAL {
        # ?film dbo:language ?language .
        # ?language rdfs:label ?languageLabel .
        FILTER (LANG(?languageLabel) = 'en')
    }

    # Optional budget information
    OPTIONAL {
        # ?film dbo:budget ?budget .
    }

    FILTER (YEAR(?releaseDate) >= 2020)
    FILTER (LANG(?title) = 'en')
}
ORDER BY DESC(?releaseDate)
LIMIT 25
"""

executor.execute_query(query_3, "Query 3: Recent Films (2020+) with Complete Metadata")
# Out:
# <h3>Query 3: Recent Films (2020+) with Complete Metadata</h3>
# <h4> Query:</h4>
# <pre><code>
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT ?film ?title ?releaseDate ?genre ?country ?language ?budget
# WHERE {
#     ?film rdf:type dbo:Film ;
#           rdfs:label ?title ;
#           dbo:releaseDate ?releaseDate .
#
#     # Optional genre information
#     OPTIONAL {
#         ?film dbo:genre ?genre .
#         ?genre rdfs:label ?genreLabel .
#         FILTER (LANG(?genreLabel) = 'en')
#     }
#
#     # Optional country information
#     OPTIONAL {
#         ?film dbo:country ?country .
#         ?country rdfs:label ?countryLabel .
#         FILTER (LANG(?countryLabel) = 'en')
#     }
#
#     # Optional language information
#     OPTIONAL {
#         ?film dbo:language ?language .
#         ?language rdfs:label ?languageLabel .
#         FILTER (LANG(?languageLabel) = 'en')
#     }
#
#     # Optional budget information
#     OPTIONAL {
#         ?film dbo:budget ?budget .
#     }
#
#     FILTER (YEAR(?releaseDate) >= 2020)
#     FILTER (LANG(?title) = 'en')
# }
# ORDER BY DESC(?releaseDate)
# LIMIT 25
# </code></pre>
# <h4> Results:</h4>
# <p>Found 25 results</p>
#                                                film  \
# 0                                  100_Years_(film)
# 1                               Force_(film_series)
# 2                                         The_Nun_2
# 3                                           Gadar_2
# 4                      Carry_On_Jatta_(film_series)
# 5                      Carry_On_Jatta_(film_series)
# 6                                  Jodi_(2022_film)
# 7                  Money_Back_Guarantee_(2023_film)
# 8                               Selfiee_(2023_film)
# 9                                            Vaathi
# 10                 Winnie-the-Pooh:_Blood_and_Honey
# 11                            Renegades_(2022_film)
# 12                             Teen_Wolf:_The_Movie
# 13                                      The_Old_Way
# 14                    Partners_in_Crime_(2022_film)
# 15                              Dhamaka_(2022_film)
# 16                              Connect_(2022_film)
# 17                                         Mindcage
# 18                                Varalaru_Mukkiyam
# 19                                  Bed_Rest_(film)
# 20                                       Pratikshya
# 21                                     Gatta_Kusthi
# 22  Diary_of_a_Wimpy_Kid:_Rodrick_Rules_(2022_film)
# 23                                 Savage_Salvation
# 24                                Troll_(2022_film)
#
#                                               title releaseDate genre country  \
# 0                                  100 Years (film)  2115-11-18  None    None
# 1                               Force (film series)  2024-08-15  None    None
# 2                                         The Nun 2  2023-09-08  None    None
# 3                                           Gadar 2  2023-08-15  None    None
# 4                      Carry On Jatta (film series)  2023-06-29  None  Canada
# 5                      Carry On Jatta (film series)  2023-06-29  None   India
# 6                                  Jodi (2022 film)  2023-05-05  None    None
# 7                  Money Back Guarantee (2023 film)  2023-04-21  None    None
# 8                               Selfiee (2023 film)  2023-02-24  None    None
# 9                                            Vaathi  2023-02-17  None    None
# 10                 Winnie-the-Pooh: Blood and Honey  2023-02-15  None    None
# 11                            Renegades (2022 film)  2023-01-30  None    None
# 12                             Teen Wolf: The Movie  2023-01-26  None    None
# 13                                      The Old Way  2023-01-06  None    None
# 14                    Partners in Crime (2022 film)  2022-12-25  None    None
# 15                              Dhamaka (2022 film)  2022-12-23  None    None
# 16                              Connect (2022 film)  2022-12-22  None    None
# 17                                         Mindcage  2022-12-16  None    None
# 18                                Varalaru Mukkiyam  2022-12-09  None    None
# 19                                  Bed Rest (film)  2022-12-07  None    None
# 20                                       Pratikshya  2022-12-02  None    None
# 21                                     Gatta Kusthi  2022-12-02  None    None
# 22  Diary of a Wimpy Kid: Rodrick Rules (2022 film)  2022-12-02  None    None
# 23                                 Savage Salvation  2022-12-02  None    None
# 24                                Troll (2022 film)  2022-12-01  None    None
#
#             language budget
# 0               None   None
# 1               None   None
# 2               None   None
# 3               None   None
# 4               None   13.5
# 5               None   13.5
# 6   Punjabi_language   None
# 7               Urdu   None
# 8               None   None
# 9               None   None
# 10              None   None
# 11              None   None
# 12              None   None
# 13              None   None
# 14              None   None
# 15              None   None
# 16   Tamil_languages   None
# 17              None   None
# 18    Tamil-language   None
# 19              None   None
# 20     Odia_language   None
# 21    Tamil_language   None
# 22              None   None
# 23              None   None
# 24              None   None

# %%
query_4 = """
SELECT ?directorName
       (COUNT(DISTINCT ?film) AS ?totalFilms)
       (MIN(YEAR(?releaseDate)) AS ?firstFilmYear)
       (MAX(YEAR(?releaseDate)) AS ?latestFilmYear)
       (MAX(YEAR(?releaseDate)) - MIN(YEAR(?releaseDate)) AS ?careerSpan)
       (SAMPLE(?recentFilmTitle) AS ?recentFilm)
WHERE {
    # ?film rdf:type dbo:Film ;
          dbo:director ?director ;
          dbo:releaseDate ?releaseDate ;
          rdfs:label ?recentFilmTitle .

    # ?director foaf:name ?directorName .

    FILTER (YEAR(?releaseDate) >= 1990)
    FILTER (LANG(?recentFilmTitle) = 'en')
}
GROUP BY ?directorName
HAVING (COUNT(DISTINCT ?film) >= 5)
ORDER BY DESC(?totalFilms) DESC(?careerSpan)
LIMIT 15
"""

executor.execute_query(query_4, "Query 4: Director Filmography Analysis")
# Out:
# <h3>Query 4: Director Filmography Analysis</h3>
# <h4> Query:</h4>
# <pre><code>
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT ?directorName
#        (COUNT(DISTINCT ?film) AS ?totalFilms)
#        (MIN(YEAR(?releaseDate)) AS ?firstFilmYear)
#        (MAX(YEAR(?releaseDate)) AS ?latestFilmYear)
#        (MAX(YEAR(?releaseDate)) - MIN(YEAR(?releaseDate)) AS ?careerSpan)
#        (SAMPLE(?recentFilmTitle) AS ?recentFilm)
# WHERE {
#     ?film rdf:type dbo:Film ;
#           dbo:director ?director ;
#           dbo:releaseDate ?releaseDate ;
#           rdfs:label ?recentFilmTitle .
#
#     ?director foaf:name ?directorName .
#
#     FILTER (YEAR(?releaseDate) >= 1990)
#     FILTER (LANG(?recentFilmTitle) = 'en')
# }
# GROUP BY ?directorName
# HAVING (COUNT(DISTINCT ?film) >= 5)
# ORDER BY DESC(?totalFilms) DESC(?careerSpan)
# LIMIT 15
# </code></pre>
# <h4> Results:</h4>
# <p>Found 15 results</p>
#                directorName totalFilms firstFilmYear latestFilmYear  \
# 0                                   26          1990           2020
# 1               Chuck Jones         19          1994           2020
# 2              Friz Freleng         18          2003           2020
# 3             Takashi Miike         16          1991           2006
# 4   Udayakantha Warnasuriya         11          1998           2019
# 5           Ram Gopal Varma         10          1990           2017
# 6                Herman Yau         10          1992           2019
# 7                    P Vasu         10          1992           2017
# 8            Joseph Sargent         10          1990           2008
# 9              Arthur Davis         10          2003           2014
# 10                Wong Jing          9          1991           2015
# 11             Roy de Silva          9          1991           2009
# 12             Bob Clampett          9          2003           2020
# 13                Tex Avery          9          2004           2020
# 14          K. S. Ravikumar          9          1997           2009
#
#    careerSpan                                recentFilm
# 0          30                         School Wars: Hero
# 1          26                           Chariots of Fur
# 2          17  Looney Tunes Golden Collection: Volume 1
# 3          15                    Dead or Alive 2: Birds
# 4          21                      President Super Star
# 5          27                      Sarkar (film series)
# 6          27              Best of the Best (1992 film)
# 7          25                             Hrudayavantha
# 8          18                                 Caroline?
# 9          11  Looney Tunes Golden Collection: Volume 1
# 10         24               Prince Charming (1999 film)
# 11         18                           Cheriyo Captain
# 12         17  Looney Tunes Golden Collection: Volume 1
# 13         16  Looney Tunes Golden Collection: Volume 2
# 14         12                              Sneham Kosam

# %%
query_5 = """
SELECT ?season ?genreLabel
       (COUNT(?film) AS ?filmCount)
       (AVG(?runtime) AS ?avgRuntime)
WHERE {
    # ?film rdf:type dbo:Film ;
          dbo:releaseDate ?releaseDate ;
          dbo:genre ?genre .

    # ?genre rdfs:label ?genreLabel .

    # Optional runtime for average calculation
    OPTIONAL {
        # ?film dbo:runtime ?runtime .
    }

    # Determine season based on release month
    BIND (
        IF(MONTH(?releaseDate) IN (12, 1, 2), "Winter",
        IF(MONTH(?releaseDate) IN (3, 4, 5), "Spring",
        IF(MONTH(?releaseDate) IN (6, 7, 8), "Summer", "Autumn")))
        AS ?season
    )

    FILTER (YEAR(?releaseDate) >= 2000)
    FILTER (LANG(?genreLabel) = 'en')
}
GROUP BY ?season ?genreLabel
HAVING (COUNT(?film) >= 5)
ORDER BY ?season DESC(?filmCount)
LIMIT 30
"""

executor.execute_query(query_5, "Query 5: Seasonal Release Patterns by Genre")
# Out:
# <h3>Query 5: Seasonal Release Patterns by Genre</h3>
# <h4> Query:</h4>
# <pre><code>
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT ?season ?genreLabel
#        (COUNT(?film) AS ?filmCount)
#        (AVG(?runtime) AS ?avgRuntime)
# WHERE {
#     ?film rdf:type dbo:Film ;
#           dbo:releaseDate ?releaseDate ;
#           dbo:genre ?genre .
#
#     ?genre rdfs:label ?genreLabel .
#
#     # Optional runtime for average calculation
#     OPTIONAL {
#         ?film dbo:runtime ?runtime .
#     }
#
#     # Determine season based on release month
#     BIND (
#         IF(MONTH(?releaseDate) IN (12, 1, 2), "Winter",
#         IF(MONTH(?releaseDate) IN (3, 4, 5), "Spring",
#         IF(MONTH(?releaseDate) IN (6, 7, 8), "Summer", "Autumn")))
#         AS ?season
#     )
#
#     FILTER (YEAR(?releaseDate) >= 2000)
#     FILTER (LANG(?genreLabel) = 'en')
# }
# GROUP BY ?season ?genreLabel
# HAVING (COUNT(?film) >= 5)
# ORDER BY ?season DESC(?filmCount)
# LIMIT 30
# </code></pre>
# <h4> Results:</h4>
# <p>Found 30 results</p>
#     season                     genreLabel filmCount             avgRuntime
# 0   Autumn                         Sitcom        15   1242.857142857142857
# 1   Autumn                          Drama        13                   4800
# 2   Autumn                   Romance film        12                2501.25
# 3   Autumn             Reality television        11   2716.363636363636364
# 4   Autumn                     Telenovela        11                     40
# 5   Autumn                         Comedy        10   1911.428571428571429
# 6   Autumn                    Documentary         9   2446.666666666666667
# 7   Autumn                      Tokusatsu         8   -171.428571428571429
# 8   Autumn              Superhero fiction         8   -171.428571428571429
# 9   Autumn                         Satire         6                   3170
# 10  Autumn               Documentary film         6                   4420
# 11  Autumn  Broadcasting of sports events         6                   3600
# 12  Autumn                        Fantasy         5                  -1560
# 13  Autumn                 Horror fiction         5                   3630
# 14  Autumn                      Docudrama         5                   4500
# 15  Autumn                   Comedy drama         5                   -156
# 16  Autumn                      Card game         5                   None
# 17  Spring                     Telenovela        19   -138.461538461538462
# 18  Spring                         Sitcom        17   1154.117647058823529
# 19  Spring                          Drama        17   2871.071428571428571
# 20  Spring                         Comedy        14                 2399.5
# 21  Spring                   Black comedy        13  40716.923076923076923
# 22  Spring                          Music        11   7058.181818181818182
# 23  Spring                   Romance film        11   1788.333333333333333
# 24  Spring             Reality television        11                   4650
# 25  Spring    Drama (film and television)        10                   1128
# 26  Spring                  Surreal humor        10                   1656
# 27  Spring           Dramatic programming         9                 3262.5
# 28  Spring                  Sketch comedy         9                   2080
# 29  Spring                  Insult comedy         8                   1905

# %%
query_advanced = """
SELECT ?seriesName
       (COUNT(?film) AS ?filmsInSeries)
       (MIN(YEAR(?releaseDate)) AS ?firstRelease)
       (MAX(YEAR(?releaseDate)) AS ?latestRelease)
       (GROUP_CONCAT(DISTINCT ?filmTitle; SEPARATOR=", ") AS ?filmTitles)
WHERE {
    # ?film rdf:type dbo:Film ;
          rdfs:label ?filmTitle ;
          dbo:releaseDate ?releaseDate ;
          dct:subject ?category .

    # ?category rdfs:label ?seriesName .

    FILTER (LANG(?filmTitle) = 'en')
    FILTER (LANG(?seriesName) = 'en')
    FILTER (CONTAINS(LCASE(?seriesName), "film series") ||
            CONTAINS(LCASE(?seriesName), "films") ||
            CONTAINS(LCASE(?seriesName), "franchise"))
    FILTER (YEAR(?releaseDate) >= 1990)
}
GROUP BY ?seriesName
HAVING (COUNT(?film) >= 3)
ORDER BY DESC(?filmsInSeries) DESC(?latestRelease)
LIMIT 20
"""

executor.execute_query(query_advanced, "Advanced: Film Series and Franchise Analysis")
# Out:
# <h3>Advanced: Film Series and Franchise Analysis</h3>
# <h4> Query:</h4>
# <pre><code>
# PREFIX dbo: <http://dbpedia.org/ontology/>
# PREFIX dbr: <http://dbpedia.org/resource/>
# PREFIX dbp: <http://dbpedia.org/property/>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
#
# SELECT ?seriesName
#        (COUNT(?film) AS ?filmsInSeries)
#        (MIN(YEAR(?releaseDate)) AS ?firstRelease)
#        (MAX(YEAR(?releaseDate)) AS ?latestRelease)
#        (GROUP_CONCAT(DISTINCT ?filmTitle; SEPARATOR=", ") AS ?filmTitles)
# WHERE {
#     ?film rdf:type dbo:Film ;
#           rdfs:label ?filmTitle ;
#           dbo:releaseDate ?releaseDate ;
#           dct:subject ?category .
#
#     ?category rdfs:label ?seriesName .
#
#     FILTER (LANG(?filmTitle) = 'en')
#     FILTER (LANG(?seriesName) = 'en')
#     FILTER (CONTAINS(LCASE(?seriesName), "film series") ||
#             CONTAINS(LCASE(?seriesName), "films") ||
#             CONTAINS(LCASE(?seriesName), "franchise"))
#     FILTER (YEAR(?releaseDate) >= 1990)
# }
# GROUP BY ?seriesName
# HAVING (COUNT(?film) >= 3)
# ORDER BY DESC(?filmsInSeries) DESC(?latestRelease)
# LIMIT 20
# </code></pre>
# <h4> Results:</h4>
# <p>Found 20 results</p>
#                       seriesName filmsInSeries firstRelease latestRelease  \
# 0   2000s English-language films           944         1998          2017
# 1   1990s English-language films           792         1990          2012
# 2           1990s American films           588         1990          2012
# 3           2000s American films           577         2000          2016
# 4   2010s English-language films           479         2000          2020
# 5           2010s American films           306         2010          2020
# 6                     2006 films           298         2006          2016
# 7                     2001 films           286         2000          2011
# 8                     2004 films           278         2002          2017
# 9                     2007 films           272         1999          2015
# 10                    2003 films           268         1998          2016
# 11                    2000 films           268         1999          2004
# 12                    1999 films           260         1998          2008
# 13                    2002 films           254         1998          2012
# 14                    2005 films           226         2004          2015
# 15                    1997 films           225         1995          2007
# 16                    2008 films           218         2008          2021
# 17    1990s Hindi-language films           204         1990          2000
# 18                    1991 films           202         1991          2004
# 19                    2017 films           200         2014          2019
#
#                                            filmTitles
# 0   $9.99, 'Twas the Night, 101 Rent Boys, 101 Rey...
# 1   (Blooper) Bunny, ...First Do No Harm, 1991: Th...
# 2   ...First Do No Harm, 12 Angry Men (1997 film),...
# 3   'Twas the Night, 10,000 Black Men Named George...
# 4   10 Hours of Walking in NYC as a Woman, 16-Love...
# 5   16-Love, 3 Day Weekend, 30 Years from Here, 7 ...
# 6   9/11: The Twin Towers, A Christmas Carol (2006...
# 7   'Twas the Night, A Crack in the Floor, A Funny...
# 8   10.5 (miniseries), A Christmas Carol (2004 fil...
# 9   2 Girls 1 Cup, A Family Lost, A Love Story (20...
# 10  15 (film), A Carol Christmas, A Foreign Affair...
# 11  101 Rent Boys, 101 Reykjavík, 24 Hours in Lond...
# 12  30 Days (1999 film), A Dog of Flanders (1999 f...
# 13  10,000 Black Men Named George, 19 Months, 24 H...
# 14  A Halfway House Christmas, A Love to Hide, A N...
# 15  ...First Do No Harm, 12 Angry Men (1997 film),...
# 16  $9.99, 199 Lives: The Travis Pastrana Story, A...
# 17  Aa Gale Lag Jaa (1994 film), Aag Aandhi Aur To...
# 18  (Blooper) Bunny, A Chinese Ghost Story III, A ...
# 19  61 Garpar Lane, 6ix Rising, A Place in the Car...
